# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Customer = pd.read_csv("Customers.csv")

# %%
Product = pd.read_csv("Products.csv")

# %%
Transaction = pd.read_csv("Transactions.csv")

# %%
Customer
# Out:
#     CustomerID        CustomerName         Region  SignupDate
# 0        C0001    Lawrence Carroll  South America  2022-07-10
# 1        C0002      Elizabeth Lutz           Asia  2022-02-13
# 2        C0003      Michael Rivera  South America  2024-03-07
# 3        C0004  Kathleen Rodriguez  South America  2022-10-09
# 4        C0005         Laura Weber           Asia  2022-08-15
# ..         ...                 ...            ...         ...
# 195      C0196         Laura Watts         Europe  2022-06-07
# 196      C0197    Christina Harvey         Europe  2023-03-21
# 197      C0198         Rebecca Ray         Europe  2022-02-27
# 198      C0199      Andrea Jenkins         Europe  2022-12-03
# 199      C0200         Kelly Cross           Asia  2023-06-11
#
# [200 rows x 4 columns]

# %%
Customer.shape
# Out:
# (200, 4)

# %%
Product
# Out:
#    ProductID              ProductName     Category   Price
# 0       P001     ActiveWear Biography        Books  169.30
# 1       P002    ActiveWear Smartwatch  Electronics  346.30
# 2       P003  ComfortLiving Biography        Books   44.12
# 3       P004            BookWorld Rug   Home Decor   95.69
# 4       P005          TechPro T-Shirt     Clothing  429.31
# ..       ...                      ...          ...     ...
# 95      P096     SoundWave Headphones  Electronics  307.47
# 96      P097       BookWorld Cookbook        Books  319.34
# 97      P098         SoundWave Laptop  Electronics  299.93
# 98      P099   SoundWave Mystery Book        Books  354.29
# 99      P100        HomeSense Sweater     Clothing  126.34
#
# [100 rows x 4 columns]

# %%
Product.shape
# Out:
# (100, 4)

# %%
Transaction
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0          T00001      C0199      P067  2024-08-25 12:38:23         1
# 1          T00112      C0146      P067  2024-05-27 22:23:54         1
# 2          T00166      C0127      P067  2024-04-25 07:38:55         1
# 3          T00272      C0087      P067  2024-03-26 22:55:37         2
# 4          T00363      C0070      P067  2024-03-21 15:10:10         3
# ..            ...        ...       ...                  ...       ...
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue   Price
# 0        300.68  300.68
# 1        300.68  300.68
# 2        300.68  300.68
# 3        601.36  300.68
# ...

# %%
Transaction.shape
# Out:
# (1000, 7)

# %% [markdown]
# #### Region (Univariate Analysis)

# %%
Customer["Region"].value_counts()
# Out:
# Region
# South America    59
# Europe           50
# North America    46
# Asia             45
# Name: count, dtype: int64

# %%
Customer["Region"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Region'>

# %%
Customer["Region"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
Customer["Region"].isnull().sum()
# Out:
# 0

# %%
Customer["CustomerID"].value_counts().sum()
# Out:
# 200

# %%
# Ensure the column is properly converted to datetime
Customer['SignupDate'] = pd.to_datetime(Customer['SignupDate'], errors='coerce')

# Check for any conversion errors
if Customer['SignupDate'].isnull().sum() > 0:
    print("There are invalid dates in the SignupDate column.")

# Extract monthly signup trends
signup_trends = Customer['SignupDate'].dt.to_period('M').value_counts().sort_index()

# Plot monthly signup trends
plt.figure(figsize=(12, 6))
signup_trends.plot(kind='line', marker='o', color='blue')
plt.title("Monthly Signup Trends")
plt.xlabel("Month")
plt.ylabel("Number of Signups")
plt.show()

# %% [markdown]
# ### Conclusions

# %% [markdown]
# There are no missing values in Region column.
#
#
#
#
#
# There are no Outliers.

# %% [markdown]
# #### Category( Univariate Analysis)

# %%
Product["Category"].value_counts()
# Out:
# Category
# Books          26
# Electronics    26
# Clothing       25
# Home Decor     23
# Name: count, dtype: int64

# %%
Product["Category"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Category'>

# %%
Product["Category"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
Product["Category"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Conclusions

# %% [markdown]
# There are no missing values.

# %% [markdown]
# #### Price

# %%
Product["Price"].describe()
# Out:
# count    100.000000
# mean     267.551700
# std      143.219383
# min       16.080000
# 25%      147.767500
# 50%      292.875000
# 75%      397.090000
# max      497.760000
# Name: Price, dtype: float64

# %%
Product["Price"].plot(kind="hist",bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
Product["Price"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
Product["Price"].skew()
# Out:
# -0.2076196737826489

# %%
Product["Price"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# ### Conclusions

# %% [markdown]
# There are no Outliers.
#
# It is left skewed.

# %% [markdown]
# #### Transactions

# %%
Transaction["Quantity"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Quantity'>

# %%
Transaction["Quantity"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
Product["Price"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
Product["Price"].skew()
# Out:
# -0.2076196737826489

# %%
Product["Price"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# ### Conclusions

# %% [markdown]
# There are no Outliers.
#
# It is left skewed.

# %% [markdown]
# ## 5 Business Insights

# %% [markdown]
# 1. Top-Selling Products: The top 10 products contribute significantly to revenue. These should be prioritized for inventory and promotions.

# %%
2.
